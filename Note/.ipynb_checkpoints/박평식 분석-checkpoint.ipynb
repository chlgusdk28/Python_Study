# %%
# 덴마 평점 분석하기 
from bs4 import BeautifulSoup
import urllib.request as req
list0 = []
list = []
list2 = []
list3 = []
list4 = []

#네이버 영화는 주소에 규칙이 있음 10001부터 시작함
#content > div.article > div.section_group.section_group_frst > div:nth-child(6) > div > div.title_area > h4 > strong
#content > div.article > div.section_group.section_group_frst > div:nth-child(6) > div > div.reporter > ul > li:nth-child(1) > div.reporter_line > dl > dt > a
#content > div.article > div.section_group.section_group_frst > div:nth-child(6) > div > div.score140 > div > ul > li > div.star_score > em

# 처음에 박평식의 평점만을 빼올 수 있을줄 알았다 근데 문제는 데이터를 하나하나 갖고올 경우 다른 평론가의 별점도 같이 갖고오는 것이 문제임
# 결국 전체 데이터를 한번에 받아온 후에 그것을 정제하는 과정을 겪어야 할 것으로 보임 
# 필요 데이터 1. 박평식인가 아닌가 > 2. 평점 > 3. 무슨영화인가 > 4. 어떻게 평가했는가 

for page in range(10):
    no = str(page+10000)
    url='https://movie.naver.com/movie/bi/mi/point.nhn?code='+no
    res =req.urlopen(url)
    #print(url)
    
    soup = BeautifulSoup(res,'html.parser')
    tests = soup.select("#content > div.article > div.section_group.section_group_frst > div")
    names = soup.select("#content > div.article > div.section_group.section_group_frst > div > div > div.reporter > ul > li > div.reporter_line > dl > dt > a") 
    contents2 = soup.select("#content > div.article > div.section_group.section_group_frst > div > div > div.reporter > ul > li > p")
    search = "허지웅"
    
    for test in tests :
            if search in test :
                print ("1")
                list0.append(name.string)
                list4.append(url)
                print(name.string)
                titles = soup.select("#content > div.article > div.mv_info_area > div.mv_info > h3 > a:nth-child(1)")
                contents = soup.select("#content > div.article > div.section_group.section_group_frst > div > div > div.reporter > ul > li > div.re_score_grp > div > div > em")
                
                for content in contents :
                    print(content.string)
                    list.append(content.string)
                for content2 in contents2 :
                    list2.append(content2.string)  
                    print(content2.string)
                for title in titles :
                    list3.append(title.string)  
                    print(title.string)   


print(list)
print(list2)
print(list3)
print(list4)
# Out:
# []
# []
# []
# []

# %%
# 박평식 평점 분석하기!!  
from bs4 import BeautifulSoup
import urllib.request as req
list0 = []
list = []
list2 = []
list3 = []


#네이버 영화는 주소에 규칙이 있음 10001부터 시작함
#content > div.article > div.section_group.section_group_frst > div:nth-child(6) > div > div.title_area > h4 > strong
#content > div.article > div.section_group.section_group_frst > div:nth-child(6) > div > div.reporter > ul > li:nth-child(1) > div.reporter_line > dl > dt > a
#content > div.article > div.section_group.section_group_frst > div:nth-child(6) > div > div.score140 > div > ul > li > div.star_score > em


for page in range(2):
    no = str(page+10000)
    url='https://movie.naver.com/movie/bi/mi/point.nhn?code='+no
    res =req.urlopen(url)
    #print(url)
    
    soup = BeautifulSoup(res,'html.parser')
    names = soup.select("#content > div.article > div.section_group.section_group_frst > div > div > div.reporter > ul > li > div.reporter_line > dl > dt > a") 
    #contents2 = soup.select("#content > div.article > div.section_group.section_group_frst > div > div > div.reporter > ul > li > p")
    
    for name in names :
            if (name.string == "허지웅") :
                list0.append(name.string)
                print(name.string)
                titles = soup.select("#content > div.article > div.mv_info_area > div.mv_info > h3 > a:nth-child(1)")
                contents = soup.select("#content > div.article > div.section_group.section_group_frst > div > div > div.reporter > ul > li")

                for content in contents :
                    print(content.string)
                    list.append(content.string)

                for title in titles :
                    list3.append(title.string)  
                    print(title.string)   

print(list0)
print(list)
print(list3)
# Out:
# 허지웅
# None
# None
# 시네마 천국
# ['허지웅']
# [None, None]
# ['시네마 천국']

# %%
from bs4 import BeautifulSoup
import urllib.request as req

nameList = []
starList = []
titleList = []
movieList = []
urlList = []
avgStarLisg = []

# 다시 생각해보기로 했다. 지금 일단 규격이 다름 
#https://movie.naver.com/movie/bi/mi/point.nhn?code=169240 참고!! 
# 이름이 |  가 붙어서 출력되는 부분 체크해야함 이부분을 제거한 후 비교했음 
#찾는 문자열을 따로 넣고 출력함 
# 만약 박평식이 있는 페이지면 해당하는 평론가 평점을 모두 출력해보도록 한다!!!!



# 하루에천개씩 할 생각!!
for page in range(5000):
    no = str(page+15000)
    url='https://movie.naver.com/movie/bi/mi/point.nhn?code='+no
    res =req.urlopen(url)
    #print(url)
    
    soup = BeautifulSoup(res,'html.parser')
    tests = soup.select("#content > div.article > div.section_group.section_group_frst > div:nth-child(6) > div > div.score140 > div > ul > li > div.score_reple > dl > dd")
  
    search = "박평식"
    avgStarTotal = ""
    
    for test in tests :
        name = test.string.strip().lstrip('| ')
        # 데이터 정리 
        if search in name :
            
            print ("---------------------------------------------")
            stars = soup.select("#content > div.article > div.section_group.section_group_frst > div:nth-child(6) > div > div.score140 > div > ul > li > div.star_score > em")
            names = soup.select("#content > div.article > div.section_group.section_group_frst > div:nth-child(6) > div > div.score140 > div > ul > li > div.score_reple > dl > dd")
            titles = soup.select("#content > div.article > div.section_group.section_group_frst > div:nth-child(6) > div > div.score140 > div > ul > li > div.score_reple > p") 
           
            

                
        
            for star in stars :
                print(star.string)
                starList.append(star.string)
                
            for name in names :
                print(name.string.strip().lstrip('| '))
                nameList.append(name.string.strip().lstrip('| '))     
                
            for title in titles : 
                print(title.string)
                titleList.append(title.string)
                movies = soup.select("#content > div.article > div.mv_info_area > div.mv_info > h3 > a")
                avgStars = soup.select("#netizen_point_tab_inner > em") 
                avgStarTotal = ""
                for movie in movies : 
                    print(movie.string)
                    movieList.append(movie.string)
                    urlList.append(url) 
                    
                for avgStar in avgStars :
                    avgStarTotal+=avgStar.string
                print(avgStarTotal)
                avgStarLisg.append(avgStarTotal)
            
                

                

print(nameList)
print(starList)
print(titleList)
print(movieList)
print(urlList)


# import pandas as pd
# # csv 만들기
# df = pd.DataFrame(data=movieList, columns=['Movie'])
# df['name'] = pd.Series(nameList)
# df['star'] = pd.Series(starList)
# df['content'] = pd.Series(titleList)
# df['URL'] = pd.Series(urlList)
# df['avgStar'] = pd.Series(avgStarLisg)

# df.to_csv("../data/navermovie_new.csv", encoding ="utf-8", index=False)
# pd.read_csv("../data/navermovie_new.csv")
# Out:
# ---------------------------------------------
# 9
# 9
# 8
# 8
# 10
# 8
# 문석
# 주성철
# 황진미
# 박평식
# 이용철
# 유지나
# 스크린으로 봐야 하는 이유를 두말해 뭣하랴
# 대부
# 9.18
# 예나 지금이나 빛나는 클래식
# 대부
# 9.18
# 현대의 고전이라 불리는 이유를 직접 확인할지어다
# 대부
# 9.18
# 세기를 넘나들 생명력!
# 대부
# 9.18
# 극장에서 안 보고 <대부>를 봤다고 말하지 마라
# 대부
# 9.18
# 남자는 무엇으로 사는가, 관찰해볼 일이다
# 대부
# 9.18
# ---------------------------------------------
# 10
# 9
# 8
# 김봉석
# 박평식
# 유지나
# 입 닥치고 당장 봐야 할 영화
# 대부 2
# 9.21
# 황홀과 전율, 속편의 최고봉!
# 대부 2
# 9.21
# 전편과 겨루는 2편, 숭고한 비장 남성미의 상징판!
# 대부 2
# 9.21
# ---------------------------------------------
# 6
# 박평식
# 그 모습 그대로 씩씩하게 돌아왔다
# 로보트 태권V
# 6.67
# ---------------------------------------------
# 3
# 박평식
# 늙수그레한 어릿광대가 온갖 재롱을 부립니다
# 핑크 팬더
#
# ---------------------------------------------
# 6
# 6
# 6
# 김봉석
# 박평식
# 황진미
# 세월이 흘러도 여전한, 관능적인 춤
# 더티 댄싱
# 9.01
# 늙지 않은 친구를 만난 반가움과 멋쩍음
# 더티 댄싱
# 9.01
# 세월이 흐르고 나니 ‘더티’는 커녕, 건전하고 순진하다
# 더티 댄싱
# 9.01
# ---------------------------------------------
# 7
# 7
# 6
# 8
# 김보연
# 박평식
# 이용철
# 유지나
# 어떤 것에 비정상적으로 집착하는 인물을 보는 것은 언제나 흥미롭다
# 불의 전차
# 8.28
# 나의 질주, 그의 영광
# 불의 전차
# 8.28
# 종교적 의미를 빼면 음악만 살아남았다
# 불의 전차
# 8.28
# 안젤리스 선율 따라 몸맘이 하나로 격동한다
# 불의 전차
# 8.28
# ---------------------------------------------
# 9
# 7
# 9
# 8
# 8
# 이용철
# 정한석
# 황진미
# 박평식
# 유지나
# 늦었으나 시기적절한 방문. 스크린으로 본다는 게 사건이다
# 알제리 전투
# 8.59
# 시대를 뛰어넘고 온 식민 투쟁의 기억
# 알제리 전투
# 8.59
# 민족해방투쟁의 모든 것이자 승리한 혁명의 전범!
# 알제리 전투
# 8.59
# 이런 만남이야말로 행운이자 횡재!
# 알제리 전투
# 8.59
# 우린 왜 영화를 만들고, 볼까?  답이 숨어 있다.
# 알제리 전투
# 8.59
# ---------------------------------------------
# 8
# 7
# 8
# 김성훈
# 박평식
# 이용철
# 너무나 늦게 당도했다
# 블러드 심플
# 7.94
# 추깃물처럼 끈적끈적 달라붙는 서스펜스
# 블러드 심플
# 7.94
# 재미로 쳐도 그들 영화 중 톱3에 든다
# 블러드 심플
# 7.94
# ---------------------------------------------
# 8
# 7
# 7
# 김성훈
# 박평식
# 이용철
# 쓸쓸하고 우울하며 무기력한 도시인의 초상
# 타이페이 스토리
# 7.87
# 시대의 톱니에 낀 떠돌이들의 권태와 불안
# 타이페이 스토리
# 7.87
# 거기 그때, 여기 지금, 낯선 기시감
# 타이페이 스토리
# 7.87
# ---------------------------------------------
# 8
# 10
# 박평식
# 유지나
# 깊고 넓고 치열한, 사색의 영화!
# 제7의 봉인
# 8.41
# 보고 또 봐도 유려하고 깊은 매혹에 잠긴다
# 제7의 봉인
# 8.41
# ---------------------------------------------
# 8
# 10
# 8
# 9
# 김보연
# 김혜리
# 박평식
# 이용철
# 답은 주지 않는다. 대신 매우 신중하고 조심스럽게 질문한다
# 고령가 소년 살인사건
# 8.63
# 한편의 영화가 꿈꿀 수 있는 거의 모든 것을 가진 영화
# 고령가 소년 살인사건
# 8.63
# 난폭한 시대와 희생자들
# 고령가 소년 살인사건
# 8.63
# 지금 와서 무슨 말을 덧붙이겠나, 이건 걸작이다
# 고령가 소년 살인사건
# 8.63
# ---------------------------------------------
# 7
# 7
# 9
# 7
# 8
# 김보연
# 박평식
# 이용철
# 허남웅
# 유지나
# 비틀스 노래의 힘+지금 봐도 신선하고 독특한 연출
# 비틀즈: 하드 데이즈 나이트
# 8.68
# 숭배할 이유가 있었지
# 비틀즈: 하드 데이즈 나이트
# 8.68
# 혁명에서 고전으로
# 비틀즈: 하드 데이즈 나이트
# 8.68
# 태초에 ‘음악의 신’ 비틀스가 있었다
# 비틀즈: 하드 데이즈 나이트
# 8.68
# 록의 전설, 볼수록 호모 루덴스 유머 만발!
# 비틀즈: 하드 데이즈 나이트
# 8.68
# ---------------------------------------------
# 7
# 8
# 8
# 박평식
# 유지나
# 이용철
# 삶의 신경증, 그 위태로운 3중주
# 가을 소나타
# 8.30
# 보이지 않는 걸 잡아내는 명작의 힘, 깊이 들여다보자
# 가을 소나타
# 8.30
# 베리만의 가족드라마를 이해하는 데는 나이가 필요하다
# 가을 소나타
# 8.30
# ---------------------------------------------
# 8
# 8
# 7
# 8
# 김혜리
# 박평식
# 이동진
# 유지나
# 희극과 비극의 완전한 도킹
# 가까이서 본 기차
# 7.71
# 체코영화 새 물결의 원류다운 희비극의 절묘한 조화
# 가까이서 본 기차
# 7.71
# 생각하는 자에겐 모든 게 희극이고 느끼는 자에겐 모든 게 비극이다
# 가까이서 본 기차
# 7.71
# 희극적 에로스 에너지의 폭파력에 경배를!
# 가까이서 본 기차
# 7.71
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /opt/anaconda3/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# /opt/anaconda3/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# /opt/anaconda3/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# /opt/anaconda3/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# /opt/anaconda3/lib/python3.8/http/client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# /opt/anaconda3/lib/python3.8/http/client.py in connect(self)
#    1423
# -> 1424             self.sock = self._context.wrap_socket(self.sock,
#    1425                                                   server_hostname=server_hostname)
#
# /opt/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# /opt/anaconda3/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# /opt/anaconda3/lib/python3.8/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# OSError: [Errno 50] Network is down
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-4-6d6947ec71d4> in <module>
#      21     no = str(page+10000)
#      22     url='https://movie.naver.com/movie/bi/mi/point.nhn?code='+no
# ---> 23     res =req.urlopen(url)
#      24     #print(url)
#      25
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# /opt/anaconda3/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#    1352             except OSError as err: # timeout error
# -> 1353                 raise URLError(err)
#    1354             r = h.getresponse()
#    1355         except:
#
# URLError: <urlopen error [Errno 50] Network is down>

# %%
avgStarLisg
# Out:
# ['9.18', '9.18', '9.18', '9.18', '9.18', '9.18', '9.21', '9.21', '9.21']

# %%
import pandas as pd
# csv 만들기
df = pd.DataFrame(data=movieList, columns=['Movie'])
df['name'] = pd.Series(nameList)
df['star'] = pd.Series(starList)
df['content'] = pd.Series(titleList)
df['URL'] = pd.Series(urlList)
df['avgStar'] = pd.Series(avgStarLisg)

df.to_csv("../data/navermovie_new.csv", encoding ="utf-8", index=False)
pd.read_csv("../data/navermovie_new.csv")
# Out:
#               Movie name  star                               content  \
# 0                대부   문석     9               스크린으로 봐야 하는 이유를 두말해 뭣하랴
# 1                대부  주성철     9                       예나 지금이나 빛나는 클래식
# 2                대부  황진미     8            현대의 고전이라 불리는 이유를 직접 확인할지어다
# 3                대부  박평식     8                          세기를 넘나들 생명력!
# 4                대부  이용철    10            극장에서 안 보고 <대부>를 봤다고 말하지 마라
# 5                대부  유지나     8                남자는 무엇으로 사는가, 관찰해볼 일이다
# 6              대부 2  김봉석    10                      입 닥치고 당장 봐야 할 영화
# 7              대부 2  박평식     9                      황홀과 전율, 속편의 최고봉!
# 8              대부 2  유지나     8          전편과 겨루는 2편, 숭고한 비장 남성미의 상징판!
# 9           로보트 태권V  박평식     6                    그 모습 그대로 씩씩하게 돌아왔다
# 10            핑크 팬더  박평식     3               늙수그레한 어릿광대가 온갖 재롱을 부립니다
# 11            더티 댄싱  김봉석     6                   세월이 흘러도 여전한, 관능적인 춤
# 12            더티 댄싱  박평식     6                 늙지 않은 친구를 만난 반가움과 멋쩍음
# 13            더티 댄싱  황진미     6        세월이 흐르고 나니 ‘더티’는 커녕, 건전하고 순진하다
# 14            불의 전차  김보연     7  어떤 것에 비정상적으로 집착하는 인물을 보는 것은 언제나 흥미롭다
# 15            불의 전차  박평식     7                          나의 질주, 그의 영광
# 16            불의 전차  이용철     6                  종교적 의미를 빼면 음악만 살아남았다
# 17            불의 전차  유지나     8               안젤리스 선율 따라 몸맘이 하나로 격동한다
# 18           알제리 전투  이용철     9       늦었으나 시기적절한 방문. 스크린으로 본다는 게 사건이다
# 19           알제리 전투  정한석     7                  시대를 뛰어넘고 온 식민 투쟁의 기억
# 20           알제리 전투  황진미     9            민족해방투쟁의 모든 것이자 승리한 혁명의 전범!
# 21           알제리 전투  박평식     8                    이런 만남이야말로 행운이자 횡재!
# 22           알제리 전투  유지나     8          우린 왜 영화를 만들고, 볼까?  답이 숨어 있다.
# 23           블러드 심플  김성훈     8                           너무나 늦게 당도했다
# 24           블러드 심플  박평식     7                  추깃물처럼 끈적끈적 달라붙는 서스펜스
# 25           블러드 심플  이용철     8                 재미로 쳐도 그들 영화 중 톱3에 든다
# 26         타이페이 스토리  김성훈     8                쓸쓸하고 우울하며 무기력한 도시인의 초상
# 27         타이페이 스토리  박평식     7                시대의 톱니에 낀 떠돌이들의 권태와 불안
# 28         타이페이 스토리  이용철     7                  거기 그때, 여기 지금, 낯선 기시감
# 29           제7의 봉인  박평식     8                    깊고 넓고 치열한, 사색의 영화!
# 30           제7의 봉인  유지나    10               보고 또 봐도 유려하고 깊은 매혹에 잠긴다
# 31      고령가 소년 살인사건  김보연     8      답은 주지 않는다. 대신 매우 신중하고 조심스럽게 질문한다
# 32      고령가 소년 살인사건  김혜리    10        한편의 영화가 꿈꿀 수 있는 거의 모든 것을 가진 영화
# 33      고령가 소년 살인사건  박평식     8                          난폭한 시대와 희생자들
# 34      고령가 소년 살인사건  이용철     9            지금 와서 무슨 말을 덧붙이겠나, 이건 걸작이다
# 35  비틀즈: 하드 데이즈 나이트  김보연     7           비틀스 노래의 힘+지금 봐도 신선하고 독특한 연출
# 36  비틀즈: 하드 데이즈 나이트  박평식     7                           숭배할 이유가 있었지
# 37  비틀즈: 하드 데이즈 나이트  이용철     9                             혁명에서 고전으로
# 38  비틀즈: 하드 데이즈 나이트  허남웅     7                  태초에 ‘음악의 신’ 비틀스가 있었다
# 39  비틀즈: 하드 데이즈 나이트  유지나     8              록의 전설, 볼수록 호모 루덴스 유머 만발!
# 40           가을 소나타  박평식     7                    삶의 신경증, 그 위태로운 3중주
# 41           가을 소나타  유지나     8         보이지 않는 걸 잡아내는 명작의 힘, 깊이 들여다보자
# 42           가을 소나타  이용철     8          베리만의 가족드라마를 이해하는 데는 나이가 필요하다
# 43        가까이서 본 기차  김혜리     8                        희극과 비극의 완전한 도킹
# 44        가까이서 본 기차  박평식     8           체코영화 새 물결의 원류다운 희비극의 절묘한 조화
# 45        가까이서 본 기차  이동진     7  생각하는 자에겐 모든 게 희극이고 느끼는 자에겐 모든 게 비극이다
# 46        가까이서 본 기차  유지나     8                희극적 에로스 에너지의 폭파력에 경배를!
#
#                                                   URL  avgStar
# 0   https://movie.naver.com/movie/bi/mi/point.nhn?...     9.18
# 1   https://movie.naver.com/movie/bi/mi/point.nhn?...     9.18
# 2   https://movie.naver.com/movie/bi/mi/point.nhn?...     9.18
# 3   https://movie.naver.com/movie/bi/mi/point.nhn?...     9.18
# 4   https://movie.naver.com/movie/bi/mi/point.nhn?...     9.18
# 5   https://movie.naver.com/movie/bi/mi/point.nhn?...     9.18
# 6   https://movie.naver.com/movie/bi/mi/point.nhn?...     9.21
# 7   https://movie.naver.com/movie/bi/mi/point.nhn?...     9.21
# 8   https://movie.naver.com/movie/bi/mi/point.nhn?...     9.21
# 9   https://movie.naver.com/movie/bi/mi/point.nhn?...     6.67
# 10  https://movie.naver.com/movie/bi/mi/point.nhn?...      NaN
# 11  https://movie.naver.com/movie/bi/mi/point.nhn?...     9.01
# 12  https://movie.naver.com/movie/bi/mi/point.nhn?...     9.01
# 13  https://movie.naver.com/movie/bi/mi/point.nhn?...     9.01
# 14  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.28
# 15  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.28
# 16  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.28
# 17  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.28
# 18  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.59
# 19  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.59
# 20  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.59
# 21  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.59
# 22  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.59
# 23  https://movie.naver.com/movie/bi/mi/point.nhn?...     7.94
# 24  https://movie.naver.com/movie/bi/mi/point.nhn?...     7.94
# 25  https://movie.naver.com/movie/bi/mi/point.nhn?...     7.94
# 26  https://movie.naver.com/movie/bi/mi/point.nhn?...     7.87
# 27  https://movie.naver.com/movie/bi/mi/point.nhn?...     7.87
# 28  https://movie.naver.com/movie/bi/mi/point.nhn?...     7.87
# 29  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.41
# 30  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.41
# 31  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.63
# 32  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.63
# 33  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.63
# 34  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.63
# 35  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.68
# 36  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.68
# 37  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.68
# 38  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.68
# 39  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.68
# 40  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.30
# 41  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.30
# 42  https://movie.naver.com/movie/bi/mi/point.nhn?...     8.30
# 43  https://movie.naver.com/movie/bi/mi/point.nhn?...     7.71
# 44  https://movie.naver.com/movie/bi/mi/point.nhn?...     7.71
# 45  https://movie.naver.com/movie/bi/mi/point.nhn?...     7.71
# 46  https://movie.naver.com/movie/bi/mi/point.nhn?...     7.71
