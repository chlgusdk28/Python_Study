# %% [markdown]
# # 데이터 다운로드 하기 - 1
# : 인터넷에서 지정된 파일을 바로 내 pc에 저장하기

# %%
import urllib.request
# URL과 지정경로 지정하기
url = "http://uta.pw/shodou/img/28/214.png"
savename = "../Data/test.png"

# 다운로드 하기 
urllib.request.urlretrieve(url, savename)
print("저장되었습니다")
# Out:
# 저장되었습니다

# %% [markdown]
# # 데이터 다운로드 하기 --02
# : 인터넷에 지정된 파일을 메모리에 올리고 저장하기

# %%
import urllib.request
# URL과 지정경로 지정하기
url = "http://uta.pw/shodou/img/28/214.png"
savename = "../Data/test02.png"

# 다운로드 하기 
mem = urllib.request.urlopen(url).read()

#파일로 저장하기
with open(savename, "wb") as f:
    f.write(mem)
print("저장 되었습니다!")
# Out:
# 저장 되었습니다!

# %%
#웹에서 데이터 추출하기
import urllib.request

#데이터 읽어 들이기 
url = "http://api.aoikujira.com/ip/ini"
res = urllib.request.urlopen(url)

data = res.read()

#문자열 변환
text = data.decode("UTF-8")
print(text)
# Out:
# [ip]
# API_URI=http://api.aoikujira.com/ip/get.php
# REMOTE_ADDR=59.187.209.41
# REMOTE_HOST=59.187.209.41
# REMOTE_PORT=59214
# HTTP_HOST=api.aoikujira.com
# HTTP_USER_AGENT=Python-urllib/3.8
# HTTP_ACCEPT_LANGUAGE=
# HTTP_ACCEPT_CHARSET=
# SERVER_PORT=80
# FORMAT=ini

# %% [markdown]
# # 매개변수를 추가해 요청을 전송하는 방법
# 기상청 RSS : http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp
# URL 뒤에 매개변수를 입력하여 지역별로 일기 정보를 가져올 수 있음.
# 전국 : 108, 서울/경기도 : 109 , 강원도 : 105, 제주특별자치도 : 184
# http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stdId=109

# %%
import urllib.request
API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
    
# 매개변수를 URL Encoding
values = {'stdId':'109'}
params = urllib.parse.urlencode(values)

# 요청전용 URL 생성
url = API+"?"+params
print(url)

data = urllib.request.urlopen(url).read()
text = data.decode('utf-8')
print(text)
# Out:
# http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stdId=109
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2021년 01월 29일 (금)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2021년 01월 29일 (금)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# 	<header>
# 		<title>전국 육상중기예보</title>
# 		<tm>202101290600</tm>
# ...

# %% [markdown]
# # BeautifulSoup으로 스크래핑 하기
# - 뷰티풀숩 : 간단하게 HTML가 XML에서 정보 추출
# - 설치 : pip install beautifulsoup4

# %%
# 기본 사용법 
from bs4 import BeautifulSoup

#html 샘플
html = """
    <html>
        <body>
            <h1>header</h1>
            <p>라인1을 서술</p>
        </body>
    </html>
    
 """
#html 분석
soup = BeautifulSoup(html, 'html.parser')
  
#원하는 부분 추출하기
h1 = soup.html.body.h1
p = soup.html.body.p
print(h1)
print(p)
# text만 출력
print ("h1=",h1.string)
print ("p=",p.string)
# Out:
# <h1>header</h1>
# <p>라인1을 서술</p>
# h1= header
# p= 라인1을 서술

# %%
#아이디값으로 정보 추출 
html = """
    <html>
        <body>
            <h1 id= title>header</h1>
            <p id="p">라인1을 서술</p>
        </body>
    </html>
    
 """
#html 분석
soup = BeautifulSoup(html, 'html.parser')
  
#원하는 부분 추출하기
title = soup.find(id = "title")
p = soup.find(id="p")

#text만 출력
print('title=', title.string)
print('p=', p.text)
# Out:
# title= header
# p= 라인1을 서술

# %%
#여러개의 요소 추출하기 
html = """
    <html>
        <body>
            <ul>
                <li><a href="http://www.naver.com">naver</a></li>
                <li><a href="http://www.daum.net">daum</a></li>
            </ul>
        </body>
    </html>
    
 """
#html 분석
soup = BeautifulSoup(html, 'html.parser')
  
#원하는 부분 추출하기
links = soup.find_all("a")
print(a)

for link in links :
    href = link.attrs['href']
    text = link.string
    print(text,href)
# Out:
# [<a href="http://www.naver.com">naver</a>, <a href="http://www.daum.net">daum</a>]
# naver http://www.naver.com
# daum http://www.daum.net

# %%
# 기상청 자료 활용하기 
from bs4 import BeautifulSoup
import urllib.request as req

url="http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109"

#data 가져오기
res =req.urlopen(url)


#뷰티풀숩으로 분석
soup = BeautifulSoup(res,'html.parser')


#원하는 데이터 추출하기
title = soup.find('title').string
wf = soup.find('wf').string

wf_list = list(wf)


list_wfs=list(wf)
except_char = ['<','b','r','/','>']
result =''

for lwf in list_wfs:
    if lwf not in except_char:
        result += lwf
print(title)
print("="*50)
print(result)
# Out:
# 기상청 육상 중기예보
# ...
# ○ (강수) 2월 1일(월) 오전에 비가 내리겠습니다. ○ (기온) 2월 1일(월)과 3일~8일(일) 아침 기온은 -9~5도, 낮 기온은 3~8도로 어제(28일, 아침최저기온 -5~0도, 낮최고기온 1~2도)보다 아침 기온은 비슷하겠고, 낮 기온은 높겠습니다. 2일 아침 기온은 -11~-7도, 낮 기온은 -3~0도로 어제보다 낮겠습니다. ○ (해상) 서해중부해상의 물결은 2월 1일(월) 오후와 2일(화) 오전에 1.0~2.5m로 일겠고, 그 밖의 날은 0.5~2.0m로 일겠습니다.

# %% [markdown]
# #Css 선택자 사용하기
# - soup.select_one() : css 선택자로 요소 하나를 추출
# -

# %%
# 기본 사용법 
from bs4 import BeautifulSoup

#html 샘플
html = """
    <html>
        <body>
            <div id = "meigen">
                <h1>위키북스</h1>
                 <ul class="items">
                    <li><a href="http://www.naver.com">naver</a></li>
                    <li><a href="http://www.daum.net">daum</a></li>
                </ul>
            </div>
        </body>
    </html>
    
 """
#html 분석하기 
soup = BeautifulSoup(html, 'html.parser')
#필요한 부분 CSS 로 추출하기


#타이틀 부분 추출하기 
h1 = soup.select_one("div#meigen > h1")  # id 는 # / class는 ./ tag는 tag명 / 자손 :>, 후손 ''
print("h1:", h1)


#목록부분 추출하기
li_list=soup.select("div#meigen > ul.items > li")
for li in li_list:
    print("li=",li.string)
    
#원하는 부분 추출하기
links = soup.find_all("div#meigen > ul.items > li > a")

for link in links :
    href = link.attrs['href']
    text = link.string
    print(text,href)
# Out:
# h1: <h1>위키북스</h1>
# li= naver
# li= daum

# %% [markdown]
# # 네이버 금융에서 환율 정보 추출하기
# https://finance.naver.com/marketindex

# %%
#미국 환율 가져오기 
from bs4 import BeautifulSoup
import urllib.request as req

# HTML 가져오기 
url = 'https://finance.naver.com/marketindex'
res = req.urlopen(url)

# HTML 분석하기 
soup = BeautifulSoup(res, "html.parser")

#데이터 추출하기
price = soup.select_one("div.head_info > span.value").string
#print(price)

list=soup.select("div.head_info > span.value")
m=[]
for m11 in list:
    m.append(m11.string)
list=soup.select("h3.h_lst > span.blind")
c =[]
for m1 in list:
    c.append(m1.string)
for i in range(4):   
    print (c[i],m[i])
# Out:
# 미국 USD 1,120.90
# 일본 JPY(100엔) 1,072.79
# 유럽연합 EUR 1,356.35
# 중국 CNY 173.11

# %% [markdown]
# # 윤동주 시인 작품 가져오기
# https://ko.wikisource.org/wiki/%EC%A0%80%EC%9E%90:%EC%9C%A4%EB%8F%99%EC%A3%BC

# %%
from bs4 import BeautifulSoup
import urllib.request as req

url = 'https://ko.wikisource.org/wiki/%EC%A0%80%EC%9E%90:%EC%9C%A4%EB%8F%99%EC%A3%BC'
res = req.urlopen(url)

# HTML 분석하기 
soup = BeautifulSoup(res, "html.parser")

#데이터 추출하기
list = soup.select("#mw-content-text > div.mw-parser-output > ul > li a")

for a in list :
    name = a.string
    if name == "증보판":
        continue
    print(name)
# Out:
# 하늘과 바람과 별과 시
# 서시
# 자화상
# 소년
# 눈 오는 지도
# 돌아와 보는 밤
# 병원
# 새로운 길
# 간판 없는 거리
# 태초의 아침
# 또 태초의 아침
# 새벽이 올 때까지
# 무서운 시간
# 십자가
# 바람이 불어
# 슬픈 족속
# 눈감고 간다
# 또 다른 고향
# 길
# 별 헤는 밤
# 흰 그림자
# 사랑스런 추억
# 흐르는 거리
# 쉽게 씌어진 시
# 봄
# 참회록
# 간(肝)
# 위로
# 팔복
# 못자는밤
# 달같이
# 고추밭
# 아우의 인상화
# 사랑의 전당
# 이적
# 비오는 밤
# 산골물
# 유언
# 창
# 바다
# 비로봉
# 산협의 오후
# 명상
# 소낙비
# 한난계
# 풍경
# 달밤
# 장
# 밤
# 황혼이 바다가 되어
# 아침
# 빨래
# 꿈은 깨어지고
# 산림
# 이런날
# 산상
# 양지쪽
# 닭
# 가슴 1
# 가슴 2
# 비둘기
# 황혼
# 남쪽 하늘
# 창공
# 거리에서
# 삶과 죽음
# 초한대
# 산울림
# 해바라기 얼굴
# 귀뚜라미와 나와
# 애기의 새벽
# 햇빛·바람
# 반디불
# 둘 다
# 거짓부리
# 눈
# 참새
# 버선본
# 편지
# 봄
# 무얼 먹구 사나
# 굴뚝
# 햇비
# 빗자루
# 기왓장 내외
# 오줌싸개 지도
# 병아리
# 조개껍질
# 겨울
# 트루게네프의 언덕
# 달을 쏘다
# 별똥 떨어진 데
# 화원에 꽃이 핀다
# 종시

# %%
# 다음영화 연간 순위 가져오기 


from bs4 import BeautifulSoup
import urllib.request as req

url = 'https://movie.daum.net/boxoffice/yearly?year=2020'
res = req.urlopen(url)

# HTML 분석하기 
soup = BeautifulSoup(res, "html.parser")


#데이터 추출하기
a_list = soup.select("div.desc_boxthumb a")
for i in a_list:
    print(i.string)
# Out:
# 남산의 부장들
# 다만 악에서 구하소서
# 반도
# 히트맨
# 테넷
# 백두산
# #살아있다
# 강철비2: 정상회담
# 담보
# 닥터 두리틀
# 삼진그룹 영어토익반
# 정직한 후보
# 도굴
# None
# 클로젯
# 오케이 마담
# 해치지않아
# 천문: 하늘에 묻는다
# 결백
# 1917
# 작은 아씨들
# 미드웨이
# 시동
# 지푸라기라도 잡고 싶은 짐승들
# 미스터 주: 사라진 VIP
# 인비저블맨
# 나쁜 녀석들: 포에버
# 국제수사
# 침입자
# 스타워즈: 라이즈 오브 스카이워커
# 스파이 지니어스
# 이웃사촌
# 온워드: 단 하루의 기적
# 소리도 없이
# 버즈 오브 프레이(할리 퀸의 황홀한 해방)
# 원더 우먼 1984
# None
# 겨울왕국 2
# 오! 문희
# 그린랜드
# 위대한 쇼맨
# 런
# 뮬란
# 내가 죽던 날
# 기생충
# 신비아파트 극장판 하늘도깨비 대 요르문간드
# 프리즌 이스케이프
# 검객
# 조제
# 사라진 시간
# 밤쉘: 세상을 바꾼 폭탄선언
# 알라딘

# %%
from bs4 import BeautifulSoup
import urllib.request as req

url = "https://media.daum.net/digital/#1"
res = req.urlopen(url)
soup = BeautifulSoup(res,"html.parser")
print("많이본뉴스 _ 뉴스")
a_list = soup.select("div.aside_g.aside_ranking > ul > li.on > div > ol:nth-child(2) > li strong > a")
for i in a_list:
    print(i.string.strip())
# Out:
# 많이본뉴스 _ 뉴스
# 조국 딸 조민, 국립중앙의료원 인턴 불합격
# 공무원시험 낙방 30대 아들 사찰서 대나무로 때려 숨지게 한 어머니
# '허용하자마자 집단감염 속출'..광주 모든 교회 대면 예배 금지
# "'교회, 지긋지긋하다'란 정서에 책임감"..개신교계 사과
# 담배 끊자마자 나타나는 '몸의 놀라운 변화'
# 1억 2천 돈다발 쓱..'여장 남자' 절도범의 정체
# 센텀시티 고층 건물에 송곳 같은 고드름이 주렁주렁..위험천만
# 노인되면 잠이 없어진다..수면부족 노화 아닌 질환 가능성 있어
# 류호정, '비서 부당해고' 주장에 "업무상 성향차로 면직한 것"
# 가슴 답답해 누워 있었는데.. 알고 보니 돌연사 징후
